# %% [markdown]
# ## Pegasus CNN-Dailymail  zero-shot for summarization

# %% [markdown]
# ### Install Libraries

# %%
# !pip install --upgrade transformers
# !pip install datasets
# !pip install rouge_score
# !pip install rouge
# !pip install sentencepiece
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 7.9 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 39.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 49.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.11.6 transformers-4.18.0
# Collecting datasets
#   Downloading datasets-2.0.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 7.3 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.5)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 48.3 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.5.1)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 53.9 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 48.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.63.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 43.2 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 56.7 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 53.7 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 135 kB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, responses, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.0.0 frozenlist-1.3.0 fsspec-2022.3.0 multidict-6.0.2 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2
# Collecting rouge_score
#   Downloading rouge_score-0.0.4-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.0.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge_score) (3.2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.21.5)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge_score) (1.15.0)
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.0.4
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge) (1.15.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 8.1 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %% [markdown]
# ### Loading the dataset

# %%
from google.colab import drive
from datasets import load_dataset, load_metric, Dataset
import pandas as pd

drive.mount('/content/drive')
path = "/content/drive/MyDrive/NN/amazon_review_dataset_processed.csv"
df = pd.read_csv(path)
df['reviewText'] = df['reviewText'].str.slice(0, 2500)
amazon = Dataset.from_pandas(df)
amazon.shape
# Out:
# Mounted at /content/drive
# (11848, 3)

# %%
import torch
if torch.cuda.is_available():
   device = torch.device("cuda")
else:
   device = torch.device("cuda")

# %% [markdown]
# ### Train-test split

# %%
NotTest_Test = amazon.train_test_split(test_size=0.1, seed=42)
NotTest = NotTest_Test["train"]
test = NotTest_Test["test"]

Train_Val = NotTest.train_test_split(test_size=0.1, seed=42)
train = Train_Val["train"]
val = Train_Val["test"]

print(train.shape, val.shape, test.shape)
# Out:
# (9596, 3) (1067, 3) (1185, 3)

# %% [markdown]
# ### Loading the Pegasus-CNN Dailymail model

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
import numpy as np
import torch
model_name = "google/pegasus-cnn_dailymail"
device = "cuda" if torch.cuda.is_available() else "cpu"
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(device)
# Out:
# Downloading:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/88.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12G [00:00<?, ?B/s]

# %% [markdown]
# ### Generating the summaries

# %%
all_outputs = []
for i in range(200):
  batch = tokenizer(test['reviewText'][i:i+1], return_tensors="pt").to(device)
  translated = model.generate(**batch, num_beams = 2, max_length=25, min_length=2, do_sample=True)
  tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
  all_outputs.append(tgt_text)

# %% [markdown]
# ### Evaluating using Rouge scores

# %%
metric = load_metric('rouge')
flattened_outputs = np.array(all_outputs).flatten()
values = metric.compute(predictions=test['summary'][:200], references = flattened_outputs, use_stemmer=True)
values
# Out:
# Downloading builder script:   0%|          | 0.00/2.16k [00:00<?, ?B/s]
# {'rouge1': AggregateScore(low=Score(precision=0.17032602038215922, recall=0.1060827676842561, fmeasure=0.12936969780945934), mid=Score(precision=0.19804070008723645, recall=0.12318763629927221, fmeasure=0.14894389657047435), high=Score(precision=0.22588076399381068, recall=0.13948729069196508, fmeasure=0.16849677850234474)),
#  'rouge2': AggregateScore(low=Score(precision=0.053922614068937606, recall=0.03189579186027436, fmeasure=0.03924985742130454), mid=Score(precision=0.07443821109446108, recall=0.0438991053913444, fmeasure=0.054056516059266285), high=Score(precision=0.0982859813797314, recall=0.057069976697209264, fmeasure=0.0699001991837544)),
#  'rougeL': AggregateScore(low=Score(precision=0.14317200000990143, recall=0.08927571073535237, fmeasure=0.10858671255647809), mid=Score(precision=0.1682557947083876, recall=0.10433923799032654, fmeasure=0.126259372259735), high=Score(precision=0.1958666664363114, recall=0.12133432208367312, fmeasure=0.14673690682286933)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.14385477894998014, recall=0.08978273732360498, fmeasure=0.10899852515492144), mid=Score(precision=0.1687013855812231, recall=0.10450258088518614, fmeasure=0.1265810144422307), high=Score(precision=0.19783266318949394, recall=0.12142627694809609, fmeasure=0.14656195390221646))}

# %% [markdown]
# ### Printing the generated summaries

# %%
print(flattened_outputs)
# Out:
# ['Average write super annoy heroine hot sex totally abrupt end book need come one allergy warn.<n>Cole allergy warn aside'
#  'cpr v202 should include option for block phone number.<n>Caller id signal particularly weak might use splitter'
#  'theres katherine garbera eve gaddy whiskey river book 1 theres sexy attorney ryder for'
#  'otmar suitner follow somewhat cult conductor yet grossly unfair one busiest active musicians career.<n>Music director 1964 1990'
#  'Young pervert tomoki sakurai constantly mind one girl.<n>Hiyori kazane girl desperately'
#  '6d new approach full frame camera probably forward-thinking production.<n>6d cameras are smaller 20mp and'
#  "long run anime series find wonderful  inuyasha '' '' one special title call total package cool character cool storyline"
#  'although procol harum always sell well come albums hit single limit three u.s. two u.k.'
#  'Eye-fi card requires internet connection pass confidential data internet various unknown entities without consent.<n>Eye-fi card'
#  'iPad air case has a built-in bluetooth keyboard and magnetic case hold place magnets.<n>Manufacturers cautious put function'
#  'dirty sexy saint book oldest three brothers clay love clays character sexy dirty care kind tough yet gentle full love'
#  "Playful streak'' genuinely enjoy spend time children will able spend time play kind game get kid hand tell"
#  'astak battery charger equip circuit protection negative delta v cut-off use charge 2 4 aa 2 4 aaa'
#  "although frank capra's wonderful life deserve place among pantheon christmas movies comparative confection 1954 still deserve special mention grant plot"
#  'offline friends online wildlands offer one massive fun world explore lot see offline play single player offline option wildlands great decision'
#  'mattel disney make toy get horrible name relate products.<n> mattel please test products produce seriously know toy production'
#  'Major League wild thing edition blu-ray disc release come everything include 2007 DVD standard definition.<n>Film shot in'
#  'jacob realizes family catch absolutely love main protagonist jacob smart well educate boy.<n>Jacob try hard fit put'
#  "zvox's website indicate size tv one support 220 320 420 range price 200 300 pay get really like crank music"
#  'Disaster preparedness kit disaster deployment available.<n>Can be purchased separately.'
#  'Range bag has several different style range bag years big empty space ton pocket obviously mean magazines others seem make anything useful'
#  "hunter page-lochard's sake movie definitely worth view.<n>'s edit wise exclude delete scenes one"
#  "Regrettably many toy toys for kids don't come with a finisher figure.<n>Some toys come with a"
#  'First safe use is respirator wear eye protection cover skin change clothe right afterwards stuff pretty nasty lungs contain harmful chemical read'
#  'Pressure cooker instant pot also like preset button regard soup stew meat etc usually use preset button adjust time since presets actually longer'
#  "Reviewer says it's time to bring back live record concert January 2015 hong kong cultural hall modern build fine"
#  'cut cord cable year ago use amazon prime hulu exclusively however husband miss sport show would previously watch find amazon.'
#  'horrible internet service yes cricket set phone check twice update third time cricket fiddle w get internet take 15 second page load '
#  'universal tablet case usually trade off general purpose case versus one custom-made specific device two unusual feature distinguish case.'
#  "miss marple joan hickson one oldest actresses take lead role major television series cast agatha christie '"
#  'People rely on digital circuitry built-in unit alone without mean verify exact temp price show small expense.<n>Cook'
#  'recently buy saw sale amazon leave review excellent price work great spend days impress s905x amlogic chipset quad core'
#  'French press coffee maker glass carafe come good quality come plastic lid make hdpe also bpa free.<n>French press'
#  'Review suggests court live secrets people around court eurus secret country separate rest democracy centre haakon must take throne follow'
#  "majikoi oh samurai girls complete collection '' release blu-ray courtesy sentai filmworks october 2012"
#  'First say work mac chance try pc experience mac quite frustrate work try make work give drawer old obsolete electronics go die try'
#  '1920x1080 21.5 inch ips tablet monitor 50 dollars 19 inch msp19u+ pass edit look like u'
#  'mattress tatame bed unique unlike another mattress ever try order twin xl guestroom amaze mattress upon delivery arrive fairly small box'
#  'oleds 2016 signature line of oled technology are clearly superior 2016 model great choice even see 2017 model original review'
#  "fisher-price take thomas diecast line learn curve's  take-along '' rename  take"
#  '1960 uc students protest against campus drug use.<n>1970 uc students protest against war in Vietnam.'
#  'Computer field 3 decades say pick review tp-link ac5 amaze simply put wireless router perform specs even perform faster'
#  'venta airwasher pull dry air vent top scooch actually see draw dust particles top rotate disk pull water three fan'
#  'young adult color film take place present era situate fictional village call mercury mercury farer couple.<n>overall plot main'
#  "Tank-style heater hook pretty easily hang wall hook gas water problem water inlet tank 1/2 '' seem somewhat restrictive flow-"
#  "elsa jade's book one favourite author latest offer 'dragon fever first new master flame series stand alone paranormal romance'"
#  "ddpai's mini mini2 line advertise supercapacitor voltage monitor shutoff.<n>panasonic gopro dji"
#  'Homemade ice cream can be frustrating to make and maintain.<n>Some recipes require two quarts of ice cream.'
#  'Older tv better newer tvs even avi cable fyi lucky enough get pre-order status.<n>roku'
#  'krampus krampus open all-too-familiar appreciate social commentary long forget family value share forgiveness love togetherness'
#  'Best gaming laptop on market today is Intel i5-6300hq 4gb model.<n>Review: Best gaming laptop'
#  '2015 paul simon fourth number one album incredible career albeit compilation combine simon garfunkel solo material.<n>'
#  'Film seem want encourage suicide grim theme cold atmospheres autopsy harken back old days horror gleefully over-the-top psycho'
#  'Office pro 2013 2 star product book first graphical interface users see awful someone decide return stone age term screen contrast vision issue'
#  'Many people want work anything want everything hand enter marriage serve serve household.<n>Many people want understand marriage work either'
#  'epa value water company annual report actually quite good ph 7.9 average tds 633 ppm calcium 79 ppm'
#  'Hub 4 USB port design plug USB 3.0 port computer also compatible USB 2.0 1.1 standards.<n>Three star item devices'
#  'furnace closet home 1150sf two story 3 bedroom attach live townhome could fit traditional whole home humidifier really happy come across trio'
#  'Black tea versatility flavor good-quality black tea arguably one versatile drink planet mean mix/blend almost infinite amount additional flavor'
#  'Canon 7G printer not working.<n>HP 7G printer not working.<n>HP 7G printer not'
#  'Procol harum gary brooker lead vocals piano celeste three string guitar harmonica recorder woods matthew fisher organ'
#  'Use ac wall charger to charge smartphones and other electronic devices.<n>A rat 4 star level able get 60 efficiency'
#  'surge suppressors survive many hit base joules rat surge suppressor one even joules rat four digits decide quick'
#  'bacillus subtilis natto includes vitamin pqq vitamin c subtilisin pyrazine gamma-poly'
#  "The jethro warner brothers/chrysalis 825646413270 benefit collector's edition.<n>The"
#  'bacillus subtilis natto includes vitamin pqq vitamin c subtilisin pyrazine gamma-poly'
#  'ed-209 look first huge robocop fan use collect various figure diecast cars.<n>well robocop'
#  '1951 make blu-ray debut stunningly restore digital re-mastered brilliant 1080p clarity classic present collectable premium 40 page'
#  'kane trilogy read order book 1 degradation book 2 separation book 3 part 3.5 completion extend epilogue degradation tatum e'
#  'harmony 950 remote review first harmony remote ive own last two leave little skeptical clearly programmable remotes lot complicate always work'
#  'bandai video game series begin 1994 always push limit fight video game.<n> storyline revolve around ruthlessness mishima'
#  'Camera gear along iPad tablet kind of number pocket place start outside go outer flap pocket set angle standard style zipper angle '
#  'dusty fan need say great big thank real go music do via thoughtful pair faithful come dream render conceptually flaw 1972 UK album'
#  'film concern federal case mary surratt whose crime may own board house conspirators abraham Lincoln meet plan'
#  "masamune shirow one favorite manga artists opportunity enjoy work back teenager creator manga hit  black magic '' "
#  'excellent miniature computer may ready replace desktop quite yet work fairly well great run electronics project main failure want use desktop use web'
#  'Nulaxy 2015 business pro rechargeable bluetooth keyboard approximately week ago far find little disappoint thing make life much easier come type'
#  'many things like product several hours waste try get work right send back pros come well package inner/outer box hold four'
#  'starring kevin costner, Emily Blunt and Matthew McConaughey.<n> well make unusual thriller  mr. brook'
#  'Bacteria and germs in food often leave use clean.<n>Use baster anymore want answer whole roast chickens love roast'
#  'Author marco tries to make sense of mystery surrounding one murderer.<n>She tries to come up with a plot'
#  "Mid-ear home studio use many's relatively inexpensive ear headphones quite good price point hand higher end's offer"
#  'Minis save money three tvs use leverage subscriptions service already exist tivo charge service plan use minis save money'
#  'steins gate is arguably one of the greatest anime series ever.<n>steins gate has many major shortcomings but'
#  "marty faranan's screenplay is based on real serial killers.<n> marty hangs religious man name han"
#  'kristin miller genre romance blurb ceo alpha werewolf drake wilder give search one true love.<n>'
#  'diatec company reinvent wheel every year keep consumer demand formula stick majestouch-2 masterpiece clean functional importantly type experience '
#  "gps unit work go 600 2535 live traffic update power update 4/30/14 use employee's computer office windows 8"
#  "ten years since  donnie darko '' appear theaters within ten years fan film people watch appreciate film continue watch"
#  'open note pet food organic comparable since grain free felidae grain free variety many protein source like little background try regular'
#  'bulb purchase three pack buy fill nine sockets two different bathroom fixtures three die use last three spar bulbs still perfect fit tight'
#  'aquaman cartoon collection adventure aquaman complete collection return us time.<n>Aquaman cartoon shy typical superhero fare certain'
#  "rhino's original album series'dave edmunds parlophone/warners/swan song'"
#  'Update see many guy bag metal d-rings around metal clip hardware carry strap zipper overlap loop small padlock etc etc etc'
#  "take-n-play collectors 2010-2013 disappoint fisher-price's 2014 tnp playset offer one exception "
#  'mora topq stainless steel knives treat mineral oil wd-40.<n>knife blade strike fire steel merely file spine'
#  'closetmaid offer one model thin cardboard paper back 3-shelf model organizer various units stack top use two insertable wooden dowel'
#  'Many strange beautiful moments throughout quiet film aim directly soul hit target participate story vision recchi family milan Italy.'
#  "chromebook 11 is a dramatic improvement on previous generations of chromebooks.<n>Reviewer says it's a"
#  'garmin nuvi 52lm 5 portable vehicle gps display window stand power cord vehicle.<n> lithium-ion cell'
#  "Rhythm 'n bluesin bayou mad dog sweet daddies pretty baby '' ace record CDchd 1422 fill follow"
#  'door closers confound many with complex instructions.<n>Door closers in particular are challenged by complex vertical face door'
#  'Device set up process is very simple for most users.<n>Belkin ac 1750 db can easily be set'
#  "Make quick work box cake mix twice ball half time hurt eat  funny look ones '' test properly happy bake k"
#  'House main drink water source bottle water brita filter read plastic bottle water environmental impact bottle horrible environment also tire run case'
#  '2 hours try get hook unable.<n>hour instructions tell help connect hell even know wait connect phone router download app'
#  'Navy destroyer girl fish gulf dinghy story emotional captain often difficult like chauvinist attitude yet protective instincts right girl strong'
#  'Tablet attach keyboard many reviewers around internet love machine find connection problem notable flaw machine get manufacture March 2014 think do correct work'
#  "Reviewer's favorite item is 99.99 rest world pouch.<n>Bag is a good fit for macbook pro"
#  'pbs home DVD version pbs show next week compile 22-track 59 minute album producer robert.<n>s'
#  'First digital camera little pocket point take decent picture easy use get better shots phone upgrade panasonic lumix dmcx'
#  'Household contain four large dog variable number 10-12 year old boys vacuum cleaner.<n>15 year mission explore strange new products'
#  'Update: 1st review obsesses screw-top food storage containers recently purchase another comparable container glad lockware 2.'
#  'Update 4-22-17 buy 22 cal also 94 shots=less 1/2 inch circle one wonder would  good.'
#  'really disappoint controllers really want like purchase two controllers figure one may issue unfortunately similar issue charge immediately get supply charge cable leave'
#  'Review: Overlap temperature regulate blanket queen.<n>Overlap temperature regulate blanket queen on vine program.<n>'
#  "Civil war film's opening credits display much film's key moments.<n>Though movie's main characters"
#  'Set of two one side King-size bed work extremely well use case purpose wife either go sleep read suit us '
#  'Older model 6s case jisoncase pu leather book folio flip design phone shell holsters skin fully protective iphone 6'
#  'The best earbuds to buy are always the best earbuds.<n>The best headphones to buy are always the best headphones'
#  'Emergency solar hand crank am/fm/noaa weather radio flashlight smart phone charger weather alert siren.<n>Solar'
#  'name-brand microwave die twice third time unavoidable serious power surge.<n>bella go backup case one go use microwave'
#  "Book takes on topic of women's right to freedom and abolition.<n>Author Sarah grimke hetty is"
#  "Green unit go straight company's website instructions need otherwise unit work well."
#  'Kon-tiki film take place norway washington dc peru raroia tuamotu islands.<n>'
#  'Book is full of love for werewolves and their stories.<n>Story is full of love for day soldier series '
#  'speaker 8.5 inch long 3 inch diameter weigh 1 pound 3 ounces per postal scale rubber cover protect bump bruise ipx6'
#  "listen review p.o.d.s newest offer  murder love '' go back listen last albums give review"
#  'Lippert hose assembly really nice say perfect get one major quibble good things first agree video say quality hose far superior '
#  "thompson argues English upper class seduce immune.<n>'' nonsense benefit beauty brain thompson''"
#  'Playable game come along frustration sometimes get set back onto shelf anyway river time.<n> Dungeon dragon game like understand'
#  'expect medieval adventure swordfights movie film fact story trial faith impose upon small group men.<n>Personal opinion better'
#  '2 hour documentary mongolian instigate  plague.<n>German jewry catastrophic downfall begin decline play important part'
#  'Original review phenominal router term performance term capability probably unparalleled setup separate guest network test.<n>Use separate guest network'
#  'reasonably price l bracket fit nikon d5300 especially useful use camera landscape orientation fit arca-swiss quick release'
#  'mr. crawford listen album guarantee afterward michael absolutely wonderful throughout whole album voice.<n>Michael soars passage'
#  'far professional photographer take seriously possible still refer hobby take mostly picture people baby nikon d40x refer.'
#  'allpowers 3nd gen battery charger 15,600mah storage capacity fast flow battery perfect charge devices couple time handle every'
#  'ever since first android htc smart phone several years ago ive own phone recall look recent phone ive own galaxy'
#  'Review may 21st may 24th June 6th add something end -- -- -- -- -- -- -- -- -- --'
#  'Film edition contain entire film run time shy two hours.<n>One scene fade another come last second less noticeable flaw'
#  'batter bowl come close big glass bowl spout pancakes lid always messy spout short oxo good grip batter bowl get zon'
#  'standalone paranormal romance short stories search continue.<n>Story become completely predictable know jasper love interest shifter know jasper go follow'
#  'Support product cooler great work pump fail year product alone would probably give 2.5 years of no support.<n>Support process'
#  "Pretty boy floyd is a film based on the life of a Kansas criminal named Peter's gangsters gun flo"
#  'endurance tire gel weird grape candy smell keep far away young children could tempt eat base smell appearance sure fragrance necessary smell better'
#  'bergman best know film deal existential question loneliness religious faith bergman felt time many stylistic conceptual theme form earlier'
#  'One real leather wait find need another case meantime order one others decide order one two bentoben iphone 5 5s'
#  'katniss selfish child volunteer sister prim know prim compete game would dead within first 5 min.<n>Haym'
#  'raspberry pi 3 HD video excellent maximum resolution 1080. expect 4k resolution.<n>Use libreelec 7.0.'
#  "Action star van damme near movie career find  hard target '' nearly indigestible film.<n>Richard"
#  'rosetta stone product tester company purchase home use list detail experience set-up work read program jump first paragraph.'
#  'Review transparency score reflect anker come update know initial product receive damage simply low usb-a compatibility.<n>Replacement'
#  'Battery pack can recharge many electronic device up to 2.1 amperes.<n>Devices with USB cable can be'
#  "scott spade's debut novel is black beach parallax.<n>Scott spade is anaerospace scientist/professional"
#  'Mac livescribe desktop software echo pen come software download web site livescribe desktop mac software sluggish glitchy watch spin wheel'
#  'bottom line several quality components one box major reduction connect wire moderate cost good sound video quality.<n>philips pull'
#  'excellent get 8 character mario luigi yoshi princess peach wario princess daisy toad waluigi still think bird'
#  "Mac mini should be combined with server app os x lion sum.<n>Apple TV's receive video stream"
#  "erotic fantasy fiction horror due rape reviewer's opinion start charm story please surprise like creativity things happen "
#  "winix plasmawave 5300 buy four years ago u450 model bigger size nearly double air vent 1 '' wide cover"
#  "cuisinart tob-260n chef's toaster convection oven relations compare breville bov800xl smart oven "
#  'dji hit homerun series quadcopter know phantom 3 already phantom 3 break rule easy flight amaze video lot review amazon already'
#  'score 3.5 5 3.3 connect test far 0.2 consider price Arduino.org board.<n> hardware problems overcome.<n>'
#  'nest cam stump smarcam review deal try figure one go foscams always stick head good ip security'
#  "Halloween is a time to celebrate and have fun with friends and family.<n>It's also a time to"
#  "fincher's best ever film critics deserve plaudits alike.<n>'s best ever film could one-off"
#  '32gb/2gb version base couple factor micro b USB lot micro b USB cable home cars 10 devices use type connection'
#  "charlie's angels' is a 1970s television show showcasing sexy women take various disguise order defeat crime "
#  'heather graham mother also actress although big name academy award ellen burstyn play evil grandmother important plot roles yes amount screen'
#  'break hearts society suite 17c leighann kopans author rat 4/5 star review.<n>Story follows three'
#  'warranty unit cover replacement unit also cover 25,000 attach equipment get damage result surge travel unit course send surge unit fail confirm surge'
#  'pn product brand price point tv deny tv look beautiful thin edge slim design make look like lead tv plasma end hang'
#  'Bike repair tool kit includes 1x tire lever 6x patch various size 1x rubber solution patch 1x metal scraper'
#  'dynarex safe-touch blue nitrile disposable gloves exam quality fairly thick tough compare many cheaply make gloves.<n>'
#  'qi-infinity 3-coils fold qi wireless charger dock triple coil reasonable price also dock use flat angle hold phone'
#  "Presentation teas offer three part user.<n>resealable leave absorb water sink create soothe meditative 'water feature glass'"
#  'Z  rat  highly recommend warm fuzzies live city night temperatures regularly dive freeze'
#  'Check connection connection super slow mine fine know router network adapter is broadband speedtest check sure well least know techy person'
#  "1971 b c's short-lived offshoot label pegasus record build serious rep amongst collectors.<n>'"
#  'Break easily begin use driver issue hp laptop use include disc install drivers usb port begin work couple minutes continue work better internal'
#  'Reviewer believes supplement gut flora is a good idea.<n>Probiotics are good for gut flora.'
#  'Season 2 watch first 6 7 episodes would think catch time-warp season 2 never die worry folks brutal tediousness begin'
#  '7d ii also multi-function button next index-finger wheel customize focus system autofocus system.<n>Design autofocus'
#  'pepper winter is one of most anticipated series of all time.'
#  '2 mm gap case protector 2 mm gap issue couple fact screen protector cut exactly touch portion screen edge contact become weird '
#  'The Alexander space center babylon 5 staffel 5 3/4/5/5 den rest aber anschauen dieser gut'
#  'book one found members govern club earlier installments ellie macdonald show us two young women find love happily ever sara'
#  'taiwan filmmaker edward yang one highly revere filmmakers know part new taiwan cinema movement.<n>Filmmaker pass'
#  'farm develop next 3-4 months time take get colony well establish productive rat subject change feel free email leave comment time progress farm'
#  'permanent wave one favorite rush cds ok reach larger audience would simply write perform better many later cds spirit radio '
#  'garmin virb elite like lot audio terrible camera big improvement new xe come decide give garmin another try things'
#  'alpatronix landtrait genuine leather rotate ipad3 case great case money.<n>Case can swivel 360 degrees to'
#  'serta prodigy heat retention issue small number us resolve portable room ac turn extra 2-3 degrees sleep important.<n>'
#  'Cat would rather go hungry thank vomit miss enough meals already far particular puzzle feeder cat mix result sniff paw halfheartedly first'
#  "Astronaut Gene cernan's life story told in documentary gemini 9."
#  "astroview scopes are better one come space probe orion sell eq1 mount separately marketable product.<n>'"
#  "Always surprising and sometimes downright bizarre behaviour in film.<n>Mattel dillon's facial hair is one of"
#  'ikea-styled furnish curve rear lift act laptop riser keep bottom laptop cool optimize airflow underneath negative product photo.<n>'
#  "hopkins 'freeeaster woods pattern u.k.'s charly record complete limit edition deluxe digibook series"]

# %% [markdown]
# ### Printing the actual summaries

# %%
print(test['summary'][:200])
# Out:
# ["decent write problem annoy heroine 's abrupt end might want pass one", 'well ... far good us use verizon fios single family home dect phone', 'shes determine go away present ryder let go easily ryder ford addi', '4.5 star underrate performance surprise delight throughout -minor vocal issue prevent full 5 star', 'entertain film fan watch previous series full fan-service', 'canon 6d bring modern tech classic shoot technique way keep photographer involve', "eight year hiatus original anime series `` inuyasha '' back first half final act", "`` salty dog '' allow procol harum sail uncharted waters-the salvo edition sound extremely good", 'eye.fi software steal account passwords review vote eye-fi shill read fast', 'excellent case lot nice feature auto sleep/wake function price right', 'author carly phillips erika wilde proud wonderful debut new series really great', 'great fun intelligent well-read creative type much lazy parent people hat english light class', 'astak ultrafast battery charger wall car chargers good price', 'remastered 2007 dvd showcases thoroughly entertain holiday classic comfortable security blanket', 'offline 1p friends online wildlands offer one massive fun world explore lot see', 'edit review get replacement part orig mattel test products children produce', 'blu-ray classic enjoyable baseball film dvd worth double dip blu-ray', 'good book excite story fleshed-out character look forward next one series', 'great tv solution fall little short surround system probabaly get 420 feature value', 'good hand emergency disaster response would eat everyday little nutrition', 'heavy duty yes high quality yes well-designed yes easy organize yes buy yes', "around movie lot `` around block '' brilliant young actor hunter page-lochard save film ignominy", 'lot fun make sure buy least one extra slam city wrestler disappointment ...', 'excellent shine hard durable finish nice spray pattern two part clear hardener get good respirator safe', 'super easy fun use make great meals lot less time experiment fun instant pot ip-duo60 7-in-1', 'uneasy mixture excellent mediocre truly dire-but still worth punt uk price', 'make watch sony vue easier good universal', 'really disppointed w phone ... poor battery life slow internet unfriendly basic feature return update', 'versatile case recent tablets usual trade-offs universal case', 'completely remastered high definition quality original film elements bbc studios post production digital media', '~~this product everyone ~~ well-made inexpensive accurate save money avoid illness ~~', 'excellent tv box great price android 6.0 bloat ware box customize want', '... french press give delectable brew good number cup make ...', 'live secrets court tell multiple point view could make interest tale', 'series interest form combat strategy also lot perverse humor fan service', 'frustrate ... could get work mouse good mouse', 'similar huion gt-220 key differences', 'extremely unique mattress double side different firmness convenient handle move make well comfortable', 'lg 2016 c6 great balance cost mature oled technology future proof industry lead visuals', "`` special edition '' kevin 's oil spill `` 5 star '' design unfortunately `` 3 star '' quality", 'brace documentary capture california university college town time change', 'best try may firmware fix port fowarding issue peaple router', 'venta airwasher really cut dust keep house humidity decent level ...', 'all-star cast bring magic great psychological insights might otherwise typical small town romance', 'large home 5 full bath family four think could probably get something like', 'fantastic action pack adrenaline pump treat dragons humour steam hea absolutely love', 'easily best value dash cam market depend bell whistle good basic feature', 'perfect way make low carb ice cream much easier use better result cusinart ice-30bc', 'move new apartment downsize mean break old tv perfect choice', 'dark christmas-themed fantasy film michael dougherty  ...
